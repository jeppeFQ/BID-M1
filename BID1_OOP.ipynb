# %% [markdown]
# <a href="https://colab.research.google.com/github/JeppeFLarsen/BID-M1-OOP/blob/main/BID1_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dagens program
#
# - Kodning sammen med mig og i de kommende workshops.
# - Åben refleksion over AI som værktøj i en kodningskontekst.
# - Øvelser fra forrige forelæsning (studenterpræsentationer).
# - Genopfriskning af objektorienteret programmering (OOP).
# - Dagens workshop og tilhørende øvelser.

# %% [markdown]
# # Kodning med Jeppe ...
#
# | **Language** | **Paradigms**                                                                 | **Description**                                                                                                                                                                                                                              |
# |--------------|-------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **R**        | Functional, Procedural                                    | Primarily used for statistical computing and data analysis, R supports functional programming but also allows for procedural and object-oriented techniques.                                                                                   |
# | **Python**   | Object-Oriented, Procedural, Functional                                      | A versatile language popular in data science, web development, and automation, Python supports multiple paradigms, including procedural, object-oriented, and functional programming.                                                           |
# | **Java**     | Object-Oriented, Concurrent, Imperative                                      | Java is heavily used in enterprise software, Android development, and large-scale systems. It focuses on the object-oriented paradigm but also supports concurrency and imperative programming.                                                |
# | **JavaScript**| Event-Driven, Functional, Procedural, Object-Oriented                        | Used mainly for web development, JavaScript is a multi-paradigm language supporting event-driven, functional, and object-oriented programming.                                                                                                 |
# | **C**        | Procedural, Imperative                                                       | A powerful system programming language, C is procedural and imperative, offering close-to-hardware performance.                                                                                                                               |
# | **C++**      | Object-Oriented, Procedural, Generic, Functional                             | Extends C with object-oriented features while also supporting procedural, functional, and generic programming, making it popular for systems and game development.                                                                             |
# | **C#**       | Object-Oriented, Procedural, Event-Driven, Functional                        | A language developed by Microsoft, C# is used in a variety of applications from web to desktop to game development. It supports object-oriented programming and functional paradigms.                                                           |
# | **Haskell**  | Functional, Declarative                                                      | Haskell is a purely functional language known for its use in academic and high-assurance systems. It emphasizes immutability, declarative programming, and type safety.                                                                         |
# | **Scala**    | Functional, Object-Oriented                                                  | A language that blends functional and object-oriented programming, Scala is often used in big data, distributed computing, and scalable systems.                                                                                               |
# | **Go**       | Procedural, Concurrent                                                       | Designed for simplicity and scalability, Go is used in cloud infrastructure and systems programming. It is procedural and supports concurrency.                                                                                               |
# | **Swift**    | Object-Oriented, Protocol-Oriented, Functional                               | Primarily used for iOS/macOS development, Swift supports multiple paradigms, including object-oriented and protocol-oriented programming.                                                                                                      |
# | **Ruby**     | Object-Oriented, Procedural, Functional                                      | Ruby is known for its elegance and simplicity, popularized by the Rails framework. It supports object-oriented, procedural, and functional paradigms.                                                                                           |
# | **PHP**      | Object-Oriented, Procedural, Functional                                      | PHP is widely used for server-side web development. It started as a procedural language but now supports object-oriented and functional programming.                                                                                            |
# | **Perl**     | Procedural, Object-Oriented, Functional                                      | Often used for scripting and system administration tasks, Perl supports procedural, object-oriented, and functional programming.                                                                                                               |
# | **Lisp**     | Functional, Procedural, Meta-programming                                     | Lisp is one of the oldest programming languages. It is primarily functional but also supports meta-programming and procedural programming.                                                                                                     |
# | **Prolog**   | Logic, Declarative                                                           | A logic programming language, Prolog is used in AI and computational linguistics. It follows a declarative paradigm, where the logic of computation is expressed without describing its control flow.                                          |
# | **SQL**      | Declarative, Set-based                                                       | SQL is a domain-specific language used for database querying and management. It follows a declarative paradigm, where users specify *what* they want rather than *how* to compute it.                                                           |
# | **MATLAB**   | Procedural, Array-Oriented, Functional                                       | Primarily used for numerical computing, MATLAB supports procedural and array-oriented programming. It is commonly used in scientific computing and engineering applications.                                                                  |
# | **Rust**     | Procedural, Functional, Concurrent, Memory-safe                              | Rust is a system programming language focused on safety and performance. It supports procedural and functional paradigms with strong concurrency and memory safety guarantees.                                                                  |
# | **Kotlin**   | Object-Oriented, Functional                                                  | Kotlin is used for Android development and web applications. It is a modern language that supports both object-oriented and functional programming, offering interoperability with Java.                                                        |
# | **Scheme**   | Functional, Procedural, Meta-programming                                     | A minimalist dialect of Lisp, Scheme emphasizes functional and meta-programming with a simple syntax.                                                                                                                                        |
# | **Erlang**   | Functional, Concurrent                                                       | Erlang is designed for building highly concurrent, distributed, and fault-tolerant systems, following functional and concurrent paradigms.                                                                                                     |
# | **F#**       | Functional, Object-Oriented, Procedural                                      | F# is part of the .NET ecosystem, with a focus on functional programming, but it also supports object-oriented and procedural paradigms.                                                                                                       |

# %% [markdown]
# Med dette fokus og baggrund vil de næste workshops introducere jer egentlig data analyse, **hvor fokus dog stadig er på kode/programmeringsaspektet af moderne dataanalyse**, jf. kursets læringsmål. Temaerne bliver:
#
# - Netværksanalyse med særlig vægt på den tematiske sammenhæng med dagens workshop.
# - Grundlæggende maskinlæring (tekstklassificering).

# %% [markdown]
# # AI som værktøj i en kodningskontekst

# %% [markdown]
# ![Screenshot 2024-09-18 at 09.29.12.png](data:image/png;base64,...)

# %% [markdown]
# ... **men husk lige at det produkt han tjener penge på er AI!**
#
# Tænk hvis Mircosoft ved udgivelsen af Word sagde: "*Dette blive blyantens død!*"

# %% [markdown]
# # Kan AI-genereret kode vedlige holde kode over tid?
#
# Forestil jer, at vi har anvendt AI til at bygge et system ved hjælp af `prompts`. Dette system er skabt gennem iterative interaktioner, hvor vi kontinuerligt forbedrer og tilpasser resultatet baseret på vores instruktioner. Med hver prompt giver vi AI’en specifikke anvisninger, som danner grundlaget for systemets funktionalitet.
#
#
# ```
# > lav et system der ...
# ```
#
# ```
# > tilføj X ...
# ```
#
# ```
# > tilføj y ...
# ```
#
#
# ```
# > osv ... [Denne proces vil typisk involvere en hel del prompts]
# ```
#
#
# Det kører, det virker. Vi bruger det i et **par år**, men så opstår der et nyt behov. Kan vi, uden nogen kodningsfærdigheder, vende tilbage til koden og tilføje nye funktioner? Kan vi overhovedet genskabe systemet 1:1, selv hvis vi i et øjeblik af klarsyn faktisk gemte vores `prompts`?
#
# *Min **personlige** og nuværende erfaringer siger nej...*
#
# *Men hvad tænker I?*

# %% [markdown]
# # De blinde leder de blinde
#
# Jeg ville jo heller ikke oversætte en tekst til kinesisk og derefter ukritisk sende den til udgivelse i Kina.
#
# ### Et læringsperspektiv
#
# Tænk på, hvad Words stavekontrol har gjort for skrivefærdigheder.

# %% [markdown]
# # Øvelser fra sidste gang

# %% [markdown]
# ## Øvelse 1:

# %%
dag = "Mandag"
ferie = False  # True or False

# Logik for vågne-tider baseret på definerede regler
if ferie:
    if dag == "Tirsdag":
        print("Du skal op kl. 6!")
    else:
        print("Du kan sove indtil kl. 10!")
else:
    if dag == "Tirsdag":
        print("Du skal op kl. 6!")
    else:
        print("Du kan sove indtil kl. 10")

# %% [markdown]
# ## Øvelse 1.1:

# %%
dag = "Onsdag"
ferie = True

# Logik for vågne-tider baseret på definerede regler
if ferie:
    if dag == "Tirsdag":
        stå_op = 6
    else:
        stå_op = 10
else:
    if dag == "Tirsdag":
        stå_op = 6
    else:
        stå_op = 7

# Print output med en f-string
ferie_status = "ikke" if not ferie else ""
print(f"I dag er {dag} og det er {ferie_status} en feriedag, så du skal op kl. {stå_op}")
# Out:
# I dag er Onsdag og det er  en feriedag, så du skal op kl. 10

# %% [markdown]
# ## Øvelse 2:

# %%
# Definer en input-variabel.
input = 10

# Definer et loop til at printe outputtet baseret inputtet.
for i in range(1, input + 1):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %% [markdown]
# ## Øvelse 2.1:

# %%
# Definer en input-variabel.
input = 10

# Definer et loop til at printe outputtet baseret inputtet.
# Loop tæller nu ned til 1, fordi: -1
for i in range(input, 0, -1):
    print("*" * i)
# Out:
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %% [markdown]
# # Dagens øvelse: Forståelse og udvidelse af AI-genereret "avanceret kode"
#
#
#
# ---
#
#
# **Del 1**: Gennemgang af eksisterende kode
#
# I får udleveret en længere kode, der er blevet genereret ved hjælp af AI. Koden kan omfatte flere klasser og funktioner, som dækker forskellige dele af et program.
#
# Din opgave er at gennemgå koden grundigt. For hver klasse eller funktion skal du:
# - Identificere formålet med koden.
# - Beskrive, hvordan koden arbejder sammen for at skabe programmets samlede funktionalitet.
# - Forstå de centrale datastrukturer, variabler og kontrolstrukturer.
#
# *Selvom I måske ikke ved præcis, hvordan AI har genereret koden, skal I fokusere på at analysere, hvad koden gør, og ikke nødvendigvis hvordan den blev til.* **Undgå Google, jeg ved godt hvad koden kan og hvordan den er kommet til, jeg vil træne jer i at reflektere over og forstå *logikken* i koden**
#
#
#
# ---
#
#
#
# **Del 2**: Diskussion og afklaring
#
# - Kør programmet (se nedenfor hvordan i kører det i Terminalen).
# - I grupper, skal I diskutere de mest komplekse eller forvirrende dele af koden, identificeret i **Del 1**, så alle er på bølgelængde.
#
# *Brug dokumentation og kommentarer i koden som hjælpemidler til at forstå dens opbygning og formål.* **Tving jer til at slå op i den officielle dokumentation. Den er skrevet efter en special standard, der er god at øve sig i at læse. Det gør jeres arbejde lettere på sigt**
#
#
#
# ---
#
# **Del 3**: Udvidelse af programmets funktionalitet
#
# Når du har opnået en grundlæggende forståelse af koden, skal du foretage en mindre ændring eller tilføjelse til programmets funktionalitet. **Vælg en lille, men meningsfuld forbedring**.
#
# *Pointen er at I skal tilføje dette, men samtidigt ændre så lidt som muligt i den oprindelige kode. Dit mål er at bevare strukturen og minimere ændringer, mens du tilføjer noget nyt*.
# - Anbefalet tilgang til øvelsen er at tilføje en ny klasse, `Pensionist`, der kan tilføjes, og en funktionalitet, der gør det muligt at printe pensionisterne i data (når I har tilføjet disse).
# - Synes i brugerfladedelen er sjovere, kan I opdatere brugerinterfacet.
#
#
#
# ---
#
# **Del 4**: Test og evaluering
#
# Test din ændring for at sikre, at programmet stadig fungerer korrekt, og at den nye funktionalitet er blevet tilføjet uden at bryde den oprindelige kode.
# - Reflektér over, hvordan det var at arbejde med AI-genereret kode:
# - Hvordan påvirker den måde, koden blev skrevet på, din evne til at modificere den?
#
# ---
#
# ### Men først en kort opsummering af OOP, så I har forudsætninger for at kunne gå til denne øvelse.

# %% [markdown]
# ## Objekter og klasser: *glorificerede datatyper*

# %%
# Definer object/klasser (en glorificeret datatype)
class Person:
    # Properties
    __navn : str # En parameter, "navn", der er en string. "__" fordi den er private
    __ID : int

    # Constructor
    def __init__(self, navn : str, id : int): # En konstrukter (en indbygget funktion i klassen), der tager to parametre. .self skal bare være der.
        self.__navn = navn                    # Der skal tilskrives data fra start.
        self.__ID = id                        # Når det er en metode, skal der altid være en parameter, self. Kunne være this., men self. er konventionen.

    # Methods
    def get_navn(self) -> str:
        return  self.__navn

    def get_id(self) -> int:
        return self.__ID

# %% [markdown]
# Definationer af klasser skal skrives i toppen, fordi Python kan ikke bruge klasser i funktioner, før klasser er defineret.
#
# **Herfra begynder det egentlige program**:

# %%
preben = Person("Preben Jensen", 1)
print(preben.get_navn())
print(preben.get_id())

sara = Person("Sara Nielsen", 2)
print(sara.get_navn())
print(sara.get_id())
# Out:
# Preben Jensen
# 1
# Sara Nielsen
# 2

# %% [markdown]
# # Object Oriented Programming (OOP)
#
# Konteksten for dagens eksempel er, at vi vil udarbejde et system, der kan registrere og administrere informationer om et lands eller en kommunes befolkning (*folketællingsregister*).
#
# Fordelen ved at gøre det i et **OOP** (*objektorienteret programmeringsparadigme*) er, at vi kan organisere implementeringen omkring vores data som "**objekter**" frem for en organisering omkring **funktioner** eller **logik**. En OOP-implementering gør det dog også mere ligetil at trække data ud sammen med deres tilhørende relationer, hvilket kan være nyttigt, når vi anvender *funktionsorienteret programmering* til *kvantitativ analyse* af data. Et aspekt, vi også kommer til at diskutere i dag.
#
# **Prompten** der driver dagens kodeworkshop er derfor:
# > Udarbejd et simpelt census register (folketællingsregister) i Python ved hjælp af objektorienteret programmering (OOP). Systemet skal kunne registrere, gemme og håndtere informationer om individer i en kommune eller et land. Hver person skal repræsenteres som et objekt med relevante egenskaber som navn, alder, køn og adresse, med særligt fokus på personers indlejring i husstande, uddannelsesinstitutioner, og arbejdspladser.
#
# **Kodespecifikke-læringsmål**:
#
# 1. Strukturere jeres data som objekter og klasser.
#
# 2. Implementere metoder, der kan opdatere, hente og vise information om individer.
#
# 3. Udnytte OOP til at organisere data effektivt og gøre koden nemmere at vedligeholde og udvide.

# %% [markdown]
# ## **Diskussion**:
#
# > `Hvorfor er jeg interesset i sådanne information, organiseret som objekter og klasse, og hvad kan jeg med den?`

# %% [markdown]
# # OOP genopfriskning
#
# **Fem centrale koncepter**:
#
# 1. Klasser og objekter.
#
# 2. Attributter og metoder.
#
# 3. *Encapsulation* ("afskærmning? indkapsling?")
#
# 4. *Inheritance* ("nedarvning")
#
# 5. *Polymorphism* ("foranderlighed")

# %% [markdown]
# # Et eksempel på "komplet" implementering i Python3
#
# Her er formålet at forstå logikken i et **større** program, snarere end at fokusere på detaljerne i hver enkelt del. Læg særligt mærke til, hvor meget af koden gentager sig gennem hele programmet. Programmet er grundlæggende opbygget af elementer, som I allerede har stiftet bekendtskab med (dog ikke alt), men de er sat sammen på en måde, der skaber et brugbart og funktionelt program.
#
# Bemærk, at den måde, jeg har kommenteret koden på her, er for at gøre det så tydeligt som muligt. Dette er **ikke** den anbefalede måde at kommentere kode på til offentlige eller delte projekter. Brug denne metode kun i kode, der er til jeres eget brug og ikke skal deles med andre (udenfor jeres projektgruppe).

# %%
#%%writefile census_modul.py

import json
import glob
import os
from datetime import datetime

class Person:
    def __init__(self, navn, alder, køn, adresse):
        self.__navn = navn
        self.__alder = alder
        self.__køn = køn
        self.__adresse = adresse
        self.__husstand = None
        self.__uddannelsesinstitution = None
        self.__arbejdsplads = None

    # Getter og setter for navn
    def get_navn(self):
        return self.__navn

    def set_navn(self, navn):
        self.__navn = navn

    # Getter og setter for alder
    def get_alder(self):
        return self.__alder

    def set_alder(self, alder):
        if alder < 0:
            raise ValueError("Alder kan ikke være negativ")
        self.__alder = alder

    # Getter og setter for køn
    def get_køn(self):
        return self.__køn

    def set_køn(self, køn):
        self.__køn = køn

    # Getter og setter for adresse
    def get_adresse(self):
        return self.__adresse

    def set_adresse(self, adresse):
        self.__adresse = adresse

    # Getter og setter for husstand
    def get_husstand(self):
        return self.__husstand

    def set_husstand(self, husstand):
        self.__husstand = husstand

    # Getter og setter for uddannelsesinstitution
    def get_uddannelsesinstitution(self):
        return self.__uddannelsesinstitution

    def set_uddannelsesinstitution(self, institution):
        self.__uddannelsesinstitution = institution

    # Getter og setter for arbejdsplads
    def get_arbejdsplads(self):
        return self.__arbejdsplads

    def set_arbejdsplads(self, arbejdsplads):
        self.__arbejdsplads = arbejdsplads

    def __str__(self):
        husstand_info = f"Husstand: {self.__husstand.get_adresse()}" if self.__husstand else "Ingen husstand"
        uddannelse_info = f"Uddannelsesinstitution: {self.__uddannelsesinstitution.get_navn()}" if self.__uddannelsesinstitution else "Ingen uddannelsesinstitution"
        arbejdsplads_info = f"Arbejdsplads: {self.__arbejdsplads.get_navn()}" if self.__arbejdsplads else "Ingen arbejdsplads"
        return f"{self.__navn}, {self.__alder} år, {self.__køn}, {self.__adresse}, {husstand_info}, {uddannelse_info}, {arbejdsplads_info}"

class Student(Person):
    def __init__(self, navn, alder, køn, adresse, studie):
        super().__init__(navn, alder, køn, adresse)
        self.__studie = studie

    # Getter og setter for studie
    def get_studie(self):
        return self.__studie

    def set_studie(self, studie):
        self.__studie = studie

    def __str__(self):
        base_info = super().__str__()
        return f"{base_info}, Studie: {self.__studie}"

class Arbejder(Person):
    def __init__(self, navn, alder, køn, adresse, jobtitel):
        super().__init__(navn, alder, køn, adresse)
        self.__jobtitel = jobtitel

    # Getter og setter for jobtitel
    def get_jobtitel(self):
        return self.__jobtitel

    def set_jobtitel(self, jobtitel):
        self.__jobtitel = jobtitel

    def __str__(self):
        base_info = super().__str__()
        return f"{base_info}, Jobtitel: {self.__jobtitel}"

class Husstand:
    def __init__(self, adresse):
        self.__adresse = adresse
        self.__personer = []

    # Getter og setter for adresse
    def get_adresse(self):
        return self.__adresse

    def set_adresse(self, adresse):
        self.__adresse = adresse

    # Getter og setter for personer
    def get_personer(self):
        return self.__personer

    def set_personer(self, personer):
        self.__personer = personer

    # Tilføj personer til en liste af personer, der tilhører klassen.
    # `self` henviser til den klasse metode tilhører. `person` er et objekt fra
    # en klasse (Person, Student, Arbejder), der tilføjes husstands-klassen.
    def tilføj_person(self, person):      # self.personer er en privat liste, der indeholder alle personer i en husstand.
        if person not in self.__personer: # Kontrollerer at person ikke allerede er tilstede i listen self.__personer
            self.__personer.append(person)# Hvis personen ikke er i self.personer, tilføjes de hertil.
            person.set_husstand(self)     # Når personen tilføjes, opdateres personens husstands attribut,
                                          # da `set_husstand` er en metode i personens klasse (Person, Student, Arbejder).
                                          # Hermed er husstands-referencen altid synkroniseret mellem de to klasser.

    def __str__(self):
        return f"Husstand på {self.__adresse} med {len(self.__personer)} personer."

class Uddannelsesinstitution:
    def __init__(self, navn):
        self.__navn = navn
        self.__personer = []

    # Getter og setter for navn
    def get_navn(self):
        return self.__navn

    def set_navn(self, navn):
        self.__navn = navn

    # Getter og setter for personer
    def get_personer(self):
        return self.__personer

    def set_personer(self, personer):
        self.__personer = personer

    def tilføj_person(self, person):
        if person not in self.__personer:
            self.__personer.append(person)
            person.set_uddannelsesinstitution(self)

    def __str__(self):
        return f"{self.__navn} med {len(self.__personer)} personer."

class Arbejdsplads:
    def __init__(self, navn):
        self.__navn = navn
        self.__personer = []

    # Getter og setter for navn
    def get_navn(self):
        return self.__navn

    def set_navn(self, navn):
        self.__navn = navn

    # Getter og setter for personer
    def get_personer(self):
        return self.__personer

    def set_personer(self, personer):
        self.__personer = personer

    def tilføj_person(self, person):
        if person not in self.__personer:
            self.__personer.append(person)
            person.set_arbejdsplads(self)

    def __str__(self):
        return f"{self.__navn} med {len(self.__personer)} ansatte."

def print_personer_af_klasse(personer, klasse):
    print(f"Personer af klasse {klasse.__name__}:")
    for person in personer:
        if isinstance(person, klasse):
            print(person)
    print()

def tilføj_person_interaktivt(personer, husstande, institutioner, arbejdspladser):
    print("Opret en ny person:")

    # Navn-validering
    while True:
        navn = input("Navn: ").strip()
        if navn:
            break
        else:
            print("Navn kan ikke være tomt. Prøv igen.")

    # Alder-validering
    while True:
        alder_input = input("Alder: ").strip()
        if alder_input.isdigit() and 0 <= int(alder_input) <= 120:
            alder = int(alder_input)
            break
        else:
            print("Ugyldig alder. Indtast et tal mellem 0 og 120.")

    # Køn-validering
    while True:
        køn = input("Køn (Mand/Kvinde): ").strip().capitalize()
        if køn in ["Mand", "Kvinde"]:
            break
        else:
            print("Ugyldigt køn. Indtast enten 'Mand' eller 'Kvinde'.")

    # Adresse-validering
    while True:
        adresse = input("Adresse: ").strip()
        if adresse:
            break
        else:
            print("Adresse kan ikke være tom. Prøv igen.")

    # Validering af om personen er student eller arbejder
    while True:
        type_person = input("Er personen en Student eller Arbejder? (S/A): ").strip().upper()
        if type_person in ["S", "A"]:
            break
        else:
            print("Ugyldigt valg. Indtast 'S' for Student eller 'A' for Arbejder.")

    # Hvis personen er en student, valider studie
    if type_person == "S":
        while True:
            studie = input("Studie: ").strip()
            if studie:
                ny_person = Student(navn, alder, køn, adresse, studie)
                break
            else:
                print("Studie kan ikke være tomt. Prøv igen.")

    # Hvis personen er en arbejder, valider jobtitel
    else:
        while True:
            jobtitel = input("Jobtitel: ").strip()
            if jobtitel:
                ny_person = Arbejder(navn, alder, køn, adresse, jobtitel)
                break
            else:
                print("Jobtitel kan ikke være tom. Prøv igen.")

    # Tilføj den nye person til listen over personer
    personer.append(ny_person)
    print(f"{ny_person.get_navn()} er nu tilføjet til systemet.") # Use the getter method to access the name


    # Tilknyt husstand
    husstand_adresse = input("Tilknyt til husstand (ID): ")
    husstand = next((h for h in husstande if h.get_adresse() == husstand_adresse), None)
    if not husstand:
        husstand = Husstand(husstand_adresse)
        husstande.append(husstand)
    husstand.tilføj_person(ny_person)

    # Tilknyt uddannelsesinstitution
    institution_navn = input("Tilknyt til uddannelsesinstitution (AAU/AU, eller Ingen): ")
    if institution_navn != "Ingen":
        institution = next((i for i in institutioner if i.get_navn() == institution_navn), None)
        if not institution:
            institution = Uddannelsesinstitution(institution_navn)
            institutioner.append(institution)
        ny_person.set_uddannelsesinstitution(institution)

    # Tilknyt arbejdsplads
    arbejdsplads_navn = input("Tilknyt til arbejdsplads (X/Y/Z, eller Ingen): ")
    if arbejdsplads_navn != "Ingen":
        arbejdsplads = next((a for a in arbejdspladser if a.get_navn() == arbejdsplads_navn), None)
        if not arbejdsplads:
            arbejdsplads = Arbejdsplads(arbejdsplads_navn)
            arbejdspladser.append(arbejdsplads)
        ny_person.set_arbejdsplads(arbejdsplads)

    print("Personen er blevet tilføjet.")

def find_seneste_fil(filnavn_mønster):
    """Finder den seneste fil baseret på et filnavn-mønster."""
    filer = glob.glob(filnavn_mønster)
    if not filer:
        return None
    seneste_fil = max(filer, key=os.path.getctime)
    return seneste_fil

def gem_data(alle_personer, husstande, institutioner, arbejdspladser):
    data = {
        "personer": [
            {
                "type": p.__class__.__name__,
                "navn": p.get_navn(),
                "alder": p.get_alder(),
                "køn": p.get_køn(),
                "adresse": p.get_adresse(),
                "husstand": p.get_husstand().get_adresse() if p.get_husstand() else None,
                "uddannelsesinstitution": p.get_uddannelsesinstitution().get_navn() if p.get_uddannelsesinstitution() else None,
                "arbejdsplads": p.get_arbejdsplads().get_navn() if p.get_arbejdsplads() else None,
                # Tilføj evt. specifikke attributter for Student/Arbejder
                "studie": p.get_studie() if isinstance(p, Student) else None,
                "jobtitel": p.get_jobtitel() if isinstance(p, Arbejder) else None,
            }
            for p in alle_personer
        ],
        "husstande": [{"adresse": h.get_adresse()} for h in husstande],
        "institutioner": [{"navn": i.get_navn()} for i in institutioner],
        "arbejdspladser": [{"navn": a.get_navn()} for a in arbejdspladser]
    }

    # Tilføj dato og tid til filnavnet
    tidsstempel = datetime.now().strftime("%Y%m%d_%H%M%S")
    filnavn = f"census_register_{tidsstempel}.json"

    with open(filnavn, 'w') as f:
        json.dump(data, f, indent=4, default=str)

def indlæs_data():
    filnavn_mønster = "census_register_*.json"
    filnavn = find_seneste_fil(filnavn_mønster)

    if not filnavn:
        raise FileNotFoundError("Ingen filer fundet.")

    with open(filnavn, 'r') as f:
        data = json.load(f)

    husstande = [Husstand(h.get('adresse', None)) for h in data.get("husstande", [])]
    institutioner = [Uddannelsesinstitution(i.get('navn', None)) for i in data.get("institutioner", [])]
    arbejdspladser = [Arbejdsplads(a.get('navn', None)) for a in data.get("arbejdspladser", [])]
    alle_personer = []

    for p in data.get("personer", []):
        if p["type"] == "Student":
            person = Student(p.get("navn"), p.get("alder"), p.get("køn"), p.get("adresse"), p.get("studie"))
        elif p["type"] == "Arbejder":
            person = Arbejder(p.get("navn"), p.get("alder"), p.get("køn"), p.get("adresse"), p.get("jobtitel"))
        else:
            person = Person(p.get("navn"), p.get("alder"), p.get("køn"), p.get("adresse"))

        # Genopret tilknytninger
        husstand = next((h for h in husstande if h.get_adresse() == p.get("husstand")), None)
        if husstand:
            person.set_husstand(husstand)

        uddannelsesinstitution = next((i for i in institutioner if i.get_navn() == p.get("uddannelsesinstitution")), None)
        if uddannelsesinstitution:
            person.set_uddannelsesinstitution(uddannelsesinstitution)

        arbejdsplads = next((a for a in arbejdspladser if a.get_navn() == p.get("arbejdsplads")), None)
        if arbejdsplads:
            person.set_arbejdsplads(arbejdsplads)

        alle_personer.append(person)

    return alle_personer, husstande, institutioner, arbejdspladser


def main():
    try:
        alle_personer, husstande, institutioner, arbejdspladser = indlæs_data()
    except FileNotFoundError:
        # Opret husstande, institutioner og arbejdspladser hvis fil ikke findes
        husstand1 = Husstand("Nørregade 12")
        husstand2 = Husstand("Hovedgade 3")
        aau = Uddannelsesinstitution("AAU")
        au = Uddannelsesinstitution("AU")
        arbejdsplads_x = Arbejdsplads("X")
        arbejdsplads_y = Arbejdsplads("Y")
        husstande = [husstand1, husstand2]
        institutioner = [aau, au]
        arbejdspladser = [arbejdsplads_x, arbejdsplads_y]
        alle_personer = []

    # Tilføj nogle initiale personer hvis der ikke er nogen
    if not alle_personer:
        p1 = Student("Anna Jensen", 30, "Kvinde", "Nørregade 12", "Kultur")
        p2 = Student("Peter Hansen", 35, "Mand", "Nørregade 12", "Teknik")
        p3 = Arbejder("Laura Smith", 25, "Kvinde", "Hovedgade 3", "Ingeniør")
        p4 = Arbejder("Jens Nielsen", 40, "Mand", "Hovedgade 3", "Chef")
        alle_personer.extend([p1, p2, p3, p4])
        p1.set_husstand(husstand1)
        p2.set_husstand(husstand1)
        p3.set_husstand(husstand2)
        p4.set_husstand(husstand2)
        p1.set_uddannelsesinstitution(aau)
        p3.set_arbejdsplads(arbejdsplads_x)
        p4.set_arbejdsplads(arbejdsplads_y)

    # Menu for interaktiv brug
    while True:
        print("\nMenu:")
        print("1. Tilføj person")
        print("2. Print alle personer")
        print("3. Print personer af en given klasse")
        print("4. Gem data")
        print("5. Afslut")

        valg = input("Vælg en option: ")

        if valg == "1":
            tilføj_person_interaktivt(alle_personer, husstande, institutioner, arbejdspladser)
        elif valg == "2":
            print("Alle personer:")
            for person in alle_personer:
                print(person)
        elif valg == "3":
            klasse_str = input("Skriv klasse (Student/Arbejder): ")
            if klasse_str == "Student":
                print_personer_af_klasse(alle_personer, Student)
            elif klasse_str == "Arbejder":
                print_personer_af_klasse(alle_personer, Arbejder)
            else:
                print("Ugyldig klasse.")
        elif valg == "4":
            gem_data(alle_personer, husstande, institutioner, arbejdspladser)
            print("Data er gemt.")
        elif valg == "5":
            break
        else:
            print("Ugyldigt valg. Prøv igen.")

if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Tilføj person
# 2. Print alle personer
# 3. Print personer af en given klasse
# 4. Gem data
# 5. Afslut
# Vælg en option: 2
# Alle personer:
# Anna Jensen, 30 år, Kvinde, Nørregade 12, Husstand: Nørregade 12, Uddannelsesinstitution: AAU, Ingen arbejdsplads, Studie: Kultur
# Peter Hansen, 35 år, Mand, Nørregade 12, Husstand: Nørregade 12, Ingen uddannelsesinstitution, Ingen arbejdsplads, Studie: Teknik
# Laura Smith, 25 år, Kvinde, Hovedgade 3, Husstand: Hovedgade 3, Ingen uddannelsesinstitution, Arbejdsplads: X, Jobtitel: Ingeniør
# Jens Nielsen, 40 år, Mand, Hovedgade 3, Husstand: Hovedgade 3, Ingen uddannelsesinstitution, Arbejdsplads: Y, Jobtitel: Chef
#
# Menu:
# 1. Tilføj person
# 2. Print alle personer
# 3. Print personer af en given klasse
# 4. Gem data
# 5. Afslut
# Vælg en option: 1
# Opret en ny person:
# Navn: Jeppe Fjeldgaard
# Alder: 30
# Køn (Mand/Kvinde): Mand
# Adresse: Peder Barkes Gade
# Er personen en Student eller Arbejder? (S/A): A
# ...

# %% [markdown]
# # Kør programmet fra terminal:
#
# 1. Gem `.py` filen (LINK TIL FIL) i en mappen.
#
# 2. Naviger til denne mappe fra terminalen
# ```
# > cd stil/til/mappen/med/filen
# ```
#
# 3. Tjek at `.py` filen er i den sti, du befinder dig i
# ```
# > ls
# ```
#
# 4. Kør `.py`-programmet
# ```
# > Python3 census_register.py
# ```

# %% [markdown]
# # Elementer i det samlede system
#
# ## 1. Import af bibliotekter
#
#
# ```
# import json
# import glob
# import os
# from datetime import datetime
# ```
#
# - `json` håndterer JSON-data (et dataformat).
# - `glob` og `os` anvendes her til at finde og håndtere filer (streng-navne)
# - `datetime` bruges til at printe aktuel dato og tid i gemte filer.
#
# ## 2. Definer Superklassen
#
# Den grundlæggende klasse repræsenterer en person i befolkningen og indeholder information om denne person. Yderligere information kan frit tilføjes til personen efter behov.
#
# Klassen indeholder metoder til at tilgå og ændre værdierne af dens attributter (se punkt 5).
#
# Derudover defineres en grundlæggende `__str__`-metode til at returnere en tekstrepræsentation af objektet (se punkt 6).
#
# ```
# class Person:
#     def __init__(self, navn, alder, køn, adresse):
#         ...
#
# ```
#
# ## 3. Definer Subklasser, der arver fra Superklassen
#
# En afledt klasse af `Person`, som tilføjer attributten `studie` for de personer, hvor dette er relevant.
#
# Klassen overskriver `__str__`-metoden fra superklassen (se punkt 6). Det samme gælder for `Arbejder`-klassen.
#
# ```
# class Student(Person):
#     def __init__(self, navn, alder, køn, adresse, studie):
#         super().__init__(navn, alder, køn, adresse)
#         self.__studie = studie
#
# ```
#
# ## 4. Definer yderlige klasse, som de andre klasser kan blive klassificeret i
#
# En klasse, der repræsenterer en `husstand`, `uddannelsesinstitution` eller `arbejdsplads`, samt de personer, der tilhører denne enhed.
#
# ```
# class Husstand:
#     def __init__(self, adresse):
#         ...
#
# ```

# %% [markdown]
# # 5.1 Metoder
#
# ### Print metoder:
#
# Lader os printe informationen i en klasse.
# ```
# def print_personer_af_klasse(personer, klasse):
#     print(f"Personer af klasse {klasse.__name__}:")
#     for person in personer:
#         if isinstance(person, klasse):
#             print(person)
#     print()
# ```
#
# ### Append metoder:
# Lader os (interaktivt i dette tilfælde) tilføje nye personer til vores objekt, og tilknytte denne person til de relevante klasser.
# ```
# def tilføj_person_interaktivt(personer, husstande, institutioner, arbejdspladser):
#     # Opretter en ny person via brugerinput
#     ...
#
# ```
#
# ### "Write" metoder:
#
# Gemmer den opdaterede data som en `JSON`-fil. Med `f-sætningen` gemmer den specifikt filen med navnet `census_register_DAGSDATO.json`
# ```
# def gem_data(alle_personer, husstande, institutioner, arbejdspladser):
#     data = {
#         "personer": [...],
#         "husstande": [...],
#         "institutioner": [...],
#         "arbejdspladser": [...]
#     }
#     # Tilføj dato og tid til filnavnet
#     tidsstempel = datetime.now().strftime("%Y%m%d_%H%M%S")
#     filnavn = f"census_register_{tidsstempel}.json"
#     with open(filnavn, 'w') as f:
#         json.dump(data, f, indent=4, default=str)
#
# ```
#
# ### "Read" metoder:
#
# Indlæser automatisk den nyeste `JSON`-fil med navnet `census_register_*.json` når programmet indlæses.
# ```
# def indlæs_data():
#     filnavn_mønster = "census_register_*.json"
#     filnavn = find_seneste_fil(filnavn_mønster)
#     if not filnavn:
#         raise FileNotFoundError("Ingen filer fundet.")
#     with open(filnavn, 'r') as f:
#         data = json.load(f)
#     ...
# ```
#
# ### main()
#
# Hovedprogrammet, der kører, når vi indlæser koden. Her er det defineret som en interaktiv menu, der tager specifikke inputs med særlige valideringskriterier (se punkt 5.2). Hvis inputs er gyldige, kalder hovedprogrammet de metoder, der er diskuteret ovenfor, uden at brugeren direkte ser disse kald.
#
# I slutningen af kodefilen, if `if __name__ == "__main__": main()`, betyder det, at filen køres som hovedprogrammet, hvis filen indlæses direkte med Python, fremfor at blive indlæst som et modul. Når programmet køres fra terminalen med `> Python3 census_register.py`, vil `main()` blive kaldt, hvilket starter en løkke, der viser menuen og håndterer inputs baseret på de angivne kriterier, indtil løkken stoppes med et `break`. Dette gør det også muligt at bruge filen som et modul ved at `import` den (se s. XXX i YY) uden at `main()`-funktionen (dvs. menuen) bliver aktiveret, hvis vi kun ønsker adgang til funktionerne og klasserne uden at køre programmet. Med andre ord: det muliggør, at vi kan bruge koden både som et program og som et modul.
#
# ```
# def main():
#     try:
#         alle_personer, husstande, institutioner, arbejdspladser = indlæs_data()
#     except FileNotFoundError:
#         ...
#     # Tilføj nogle initiale personer hvis der ikke er nogen
#     ...
#     # Menu for interaktiv brug
#     while True:
#         print("\nMenu:")
#         print("1. Tilføj person")
#         print("2. Print alle personer")
#         print("3. Print personer af en given klasse")
#         print("4. Gem data")
#         print("5. Afslut")
#         valg = input("Vælg en option: ")
#         if valg == "1":
#             tilføj_person_interaktivt(alle_personer, husstande, institutioner, arbejdspladser)
#         elif valg == "2":
#             ...
#         elif valg == "3":
#             ...
#         elif valg == "4":
#             gem_data(alle_personer, husstande, institutioner, arbejdspladser)
#         elif valg == "5":
#             break
#         else:
#             print("Ugyldigt valg. Prøv igen.")
#
# if __name__ == "__main__":
#     main()
# ```

# %% [markdown]
# ### Programmet indlæst som `module`

# %% [markdown]
# ```
# %%writefile census_modul.py
# ```

# %%
import census_modul

# %%
husstand = Husstand("005")
person = Person("Anna Jensen", 30, "Kvinde", "Nørregade 33")
husstand.tilføj_person(person)

# %%
print(husstand)
print(person)
# Out:
# Husstand på 005 med 1 personer.
# Anna Jensen, 30 år, Kvinde, Nørregade 33, Husstand: 005, Ingen uddannelsesinstitution, Ingen arbejdsplads

# %% [markdown]
# ## 5.2 Getter- og setter-metoder
#
# Bemærk at jeg ikke har fulgt Haslam's mere "korrekte" konventioner med at definere datatypen. Det er altså ikke nødvendigt, men det er god stil (selvom det æstetisk ser grimt ud...)
#
# ```
# def get_navn(self):
#     return self.__navn
#
# def set_navn(self, navn):
#     self.__navn = navn
# ```
#
#
#
# ```
# def get_navn(self) -> str:
#     return  self.__navn
# ```
#
# Eksempler på getter- og setter-metoder i praksis:

# %%
person_1 = Person("Anna Nielsen", 30, "Kvinde", "Nørregade 12")
student_1 = Student("Peter Larsen", 35, "Mand", "Nørregade 12", "Teknik")

# %%
print(person_1.get_navn())
print(student_1.get_navn())
# Out:
# Anna Nielsen
# Peter Larsen

# %%
person_1.set_navn("Anna-Lise Jensen")
student_1.set_navn("Peter Jensen")

# %%
print(person_1.get_navn())
print(student_1.get_navn())
# Out:
# Anna-Lise Jensen
# Peter Jensen

# %%
aau = Uddannelsesinstitution("AAU")

# %%
print(aau.get_navn())
# Out:
# Aalborg Universitet

# %%
aau.set_navn("Aalborg Universitet")

# %%
print(aau.get_navn())
# Out:
# Aalborg Universitet

# %% [markdown]
# **Gettere** og **settere** er direkte relateret til konceptet om *encapsulation* og *validering*. Vi bruger dem til at "beskytte" objektets interne tilstand og konventioner. Dette øger kontrollen, så hvis systemet overdrages til en ny medarbejder, er denne ikke frit stillet til at ændre det uden hensyntagen til de etablerede regler.
#
# Ved at gøre attributterne private med `__*`, kan de kun tilgås gennem **getter-** og **setter-**metoder. I vores tilfælde, med Uddannelsesinstitution-klassen, kan det være relevant at definere generelle konventioner for, hvordan navnene skal skrives, og at begrænse adgangen til at ændre dem (eller helt gøre dem utilgængelige). Dette gælder også for metoderne `gem_data` og `indlæs_data`, som bliver betydeligt mere komplekse, når attributterne er private.
#
# Vi kan også tilføje logik til **setter-**metoderne, så de kun accepterer gyldige værdier. Dette sikrer, at systemet forbliver konsistent, selv hvis det overdrages til en ny medarbejder. For eksempel:
#
# ```
# def set_alder(self, alder):
#     if alder < 0:
#         raise ValueError("Alder kan ikke være negativ")
#     self.__alder = alder
#
# ```
#
# eller
#
# ```
# while True:
#         type_person = input("Er personen en Student eller Arbejder? (S/A): ").strip().upper()
#         if type_person in ["S", "A"]:
#             break
#         else:
#             print("Ugyldigt valg. Indtast 'S' for Student eller 'A' for Arbejder.")
# ```
#
# MEN i Python-miljøet er der et princip om "*We are all consenting adults*". Det betyder, at man ofte ser, at private attributter ikke anvendes i offentlig tilgængelig kode. Dette princip antager, at udviklere selv vil handle ansvarligt og ikke misbruge eller ændre intern kode på en måde, der bryder med forventningerne til, hvordan klasser og objekter skal bruges.
#
# ## 5.2 Eksempel uden getter- og setter-metoder

# %%
class Person:
    def __init__(self, navn, alder, køn):
        self.navn = navn
        self.alder = alder
        self.køn = køn

    def __str__(self):
        return f"Navn: {self.navn}, Alder: {self.alder}, Køn: {self.køn}"


class Student(Person):
    def __init__(self, navn, alder, køn, studie):
        super().__init__(navn, alder, køn)
        self.studie = studie

    def __str__(self):
        return f"{super().__str__()}, Studie: {self.studie}"


class Arbejder(Person):
    def __init__(self, navn, alder, køn, job):
        super().__init__(navn, alder, køn)
        self.job = job

    def __str__(self):
        return f"{super().__str__()}, Job: {self.job}"


class Husstand:
    def __init__(self, adresse):
        self.adresse = adresse
        self.beboere = []

    def tilføj_beboer(self, person):
        self.beboere.append(person)

    def __str__(self):
        beboere_str = "\n".join(str(beboer) for beboer in self.beboere)
        return f"Adresse: {self.adresse}\nBeboere:\n{beboere_str}"


class Uddannelsesinstitution:
    def __init__(self, navn):
        self.navn = navn
        self.studerende = []

    def tilføj_studerende(self, student):
        self.studerende.append(student)

    def __str__(self):
        studerende_str = "\n".join(str(student) for student in self.studerende)
        return f"Uddannelsesinstitution: {self.navn}\nStuderende:\n{studerende_str}"


class Arbejdsplads:
    def __init__(self, navn):
        self.navn = navn
        self.arbejdere = []

    def tilføj_arbejder(self, arbejder):
        self.arbejdere.append(arbejder)

    def __str__(self):
        arbejdere_str = "\n".join(str(arbejder) for arbejder in self.arbejdere)
        return f"Arbejdsplads: {self.navn}\nArbejdere:\n{arbejdere_str}"


# Opretter personer
p1 = Person("Alice", 30, "Kvinde")
p2 = Person("Bob", 24, "Mand")

# Opretter studerende og arbejdere
s1 = Student("Charlie", 22, "Mand", "Software Engineering")
a1 = Arbejder("Diana", 28, "Kvinde", "Læge")

# Opretter husstand og tilføjer personer
husstand = Husstand("Elm Street 123")
husstand.tilføj_beboer(p1)
husstand.tilføj_beboer(p2)

# Opretter uddannelsesinstitution og tilføjer studerende
udd_institution = Uddannelsesinstitution("Aarhus Universitet")
udd_institution.tilføj_studerende(s1)

# Opretter arbejdsplads og tilføjer arbejdere
arbejdsplads = Arbejdsplads("Aarhus Universitetshospital")
arbejdsplads.tilføj_arbejder(a1)

# %%
print(p1)
# Out:
# Navn: Anna-Lise Nielsen, Alder: 30, Køn: Kvinde

# %%
p1.navn = "Anna-Lise Nielsen"

# %%
print(p1)
# Out:
# Navn: Anna-Lise Nielsen, Alder: 30, Køn: Kvinde

# %% [markdown]
# # 6. `__str__`
#
# `__str__`-metoden implementeres for at definere, hvordan en klasse repræsenteres som en streng. Med andre ord, hvordan data fra klassen bliver præsenteret, når den printes i terminalen.
#
# Metoden bliver automatisk kaldt, når vi bruger print()-funktionen på et objekt af klassen.
#
# For eksempel, ved at implementere __str__ kan vi sikre, at når vi printer eller tilgår information fra et objekt, bliver den præsenteret på en meningsfuld måde som en sætning i stedet for blot som en liste af datapunkter.
#
# ```
# def __str__(self):
#     husstand_info = f"Husstand: {self.__husstand.get_adresse()}" if self.__husstand else "Ingen husstand"
#     uddannelse_info = f"Uddannelsesinstitution: {self.__uddannelsesinstitution.get_navn()}" if self.__uddannelsesinstitution else "Ingen uddannelsesinstitution"
#     arbejdsplads_info = f"Arbejdsplads: {self.__arbejdsplads.get_navn()}" if self.__arbejdsplads else "Ingen arbejdsplads"
#     return f"{self.__navn}, {self.__alder} år, {self.__køn}, {self.__adresse}, {husstand_info}, {uddannelse_info}, {arbejdsplads_info}"
#
# ```

# %% [markdown]
# # Opgavens tema: Er dette et system der er fleksibelt, genanvendeligt og nemt at vedligeholde?
